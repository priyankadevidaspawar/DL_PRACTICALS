# %% [markdown]
# <a href="https://colab.research.google.com/github/priyankadevidaspawar/DL_PRACTICALS/blob/main/SIMPLE_RNN.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import torch
import torch.nn as nn

# Define a simple RNN model
class SimpleRNN(nn.Module):
    def __init__(self, input_size, hidden_size, num_layers):
        super(SimpleRNN, self).__init__()
        self.rnn = nn.RNN(input_size, hidden_size, num_layers, batch_first=True)

    def forward(self, x):
        out, _ = self.rnn(x)
        return out

# Instantiate the model
input_size = 10  # Replace with your input size
hidden_size = 20  # Replace with your desired hidden size
num_layers = 2  # Replace with the number of layers
model = SimpleRNN(input_size, hidden_size, num_layers)

# Define toy sequence data and target
sequence = torch.randn(5, 3, input_size)  # Replace 5 with the batch size
target = torch.randn(5, 3, hidden_size)  # Use hidden_size for the target

# Loss and optimization
criterion = nn.MSELoss()
optimizer = torch.optim.Adam(model.parameters(), lr=0.01)

# Training loop
num_epochs = 100
for epoch in range(num_epochs):
    optimizer.zero_grad()
    output = model(sequence)
    loss = criterion(output, target)
    loss.backward()
    optimizer.step()
    print(f"Epoch [{epoch+1}/{num_epochs}], Loss: {loss.item():.4f}")
# Out:
# Epoch [1/100], Loss: 1.0812
# Epoch [2/100], Loss: 0.9828
# Epoch [3/100], Loss: 0.8994
# Epoch [4/100], Loss: 0.8296
# Epoch [5/100], Loss: 0.7709
# Epoch [6/100], Loss: 0.7204
# Epoch [7/100], Loss: 0.6756
# Epoch [8/100], Loss: 0.6350
# Epoch [9/100], Loss: 0.5977
# Epoch [10/100], Loss: 0.5631
# Epoch [11/100], Loss: 0.5309
# Epoch [12/100], Loss: 0.5007
# Epoch [13/100], Loss: 0.4724
# Epoch [14/100], Loss: 0.4461
# Epoch [15/100], Loss: 0.4220
# Epoch [16/100], Loss: 0.3998
# Epoch [17/100], Loss: 0.3796
# Epoch [18/100], Loss: 0.3610
# Epoch [19/100], Loss: 0.3437
# Epoch [20/100], Loss: 0.3276
# Epoch [21/100], Loss: 0.3128
# Epoch [22/100], Loss: 0.2995
# Epoch [23/100], Loss: 0.2875
# Epoch [24/100], Loss: 0.2767
# Epoch [25/100], Loss: 0.2669
# Epoch [26/100], Loss: 0.2578
# Epoch [27/100], Loss: 0.2492
# Epoch [28/100], Loss: 0.2411
# Epoch [29/100], Loss: 0.2336
# Epoch [30/100], Loss: 0.2267
# Epoch [31/100], Loss: 0.2207
# Epoch [32/100], Loss: 0.2154
# Epoch [33/100], Loss: 0.2107
# Epoch [34/100], Loss: 0.2066
# Epoch [35/100], Loss: 0.2029
# Epoch [36/100], Loss: 0.1996
# Epoch [37/100], Loss: 0.1964
# Epoch [38/100], Loss: 0.1934
# Epoch [39/100], Loss: 0.1905
